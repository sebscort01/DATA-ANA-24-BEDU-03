# %%
#import de mi funcio generica
import numpy as np
from utils_distribuciones import generar_distribucion

# %%
mu,sigma = 0,1 
#mu = media, sigma = desv estandar
dist_normal = np.random.normal(mu,sigma, 1000)

# %%
#uso de nuestra funciongenerica
generar_distribucion(dist_normal, 'Distribución normal')
# Out:
# Distribución normal: Asimetria: -0.17, Curtosis: 0.07

# %% [markdown]
# ### Distribución sesgada a la derecha

# %%
dist_sesgada = np.random.exponential(1,1000)

#uso de nuestra  funcion generica
generar_distribucion(dist_sesgada, 'Distribución Sesgada a ala Derecha')
# Out:
# Distribución Sesgada a ala Derecha: Asimetria: 2.05, Curtosis: 5.93

# %% [markdown]
# ### Distribución sesgada a Izquierda

# %%
dist_sesgada_izq = -np.random.exponential(1, 1000)

# Uso de nuestra funcion generica
generar_distribucion(dist_sesgada_izq, 'Distribucion Sesgada a la Izquierda')
# Out:
# Distribucion Sesgada a la Izquierda: Asimetria: -2.02, Curtosis: 5.76

# %%
dist_bimodal = np.concatenate(
    [
        np.random.normal(-2, 1, 500),
        np.random.normal(3, 1, 500)
    ]
)

# Uso de nuestra funcion generica
generar_distribucion(dist_bimodal, 'Distribucion Bimodal')
# Out:
# Distribucion Bimodal: Asimetria: 0.01, Curtosis: -1.49

# %%
dist_uniforme = np.random.uniform(-1, 1, 1000)

# Uso de nuestra funcion generica
generar_distribucion(dist_uniforme, 'Distribucion Uniforme')
# Out:
# Distribucion Uniforme: Asimetria: 0.01, Curtosis: -1.22

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data = pd.read_csv(r"E:\Mt y Dip\Bedu\Modulo 3 Analisis de datos con python\DATA-ANA-24-BEDU-02\Ejemplo_04_Salary_Professions.csv")
data.head()
# Out:
#   FIRST NAME   LAST NAME SEX         DOJ CURRENT DATE DESIGNATION   AGE  \
# 0     TOMASA       ARMEN   F   5-18-2014   01-07-2016     Analyst  21.0
# 1      ANNIE         NaN   F         NaN   01-07-2016   Associate   NaN
# 2      OLIVE        ANCY   F   7-28-2014   01-07-2016     Analyst  21.0
# 3     CHERRY     AQUILAR   F  04-03-2013   01-07-2016     Analyst  22.0
# 4       LEON  ABOULAHOUD   M  11-20-2014   01-07-2016     Analyst   NaN
#
#    SALARY        UNIT  LEAVES USED  LEAVES REMAINING  RATINGS  PAST EXP
# 0   44570     Finance         24.0               6.0      2.0         0
# 1   89207         Web          NaN              13.0      NaN         7
# 2   40955     Finance         23.0               7.0      3.0         0
# 3   45550          IT         22.0               8.0      3.0         0
# 4   43161  Operations         27.0               3.0      NaN         3

# %%
# Convertir columna Salary a numerico
data['SALARY'] = pd.to_numeric(data['SALARY'], errors='coerce')

# Eliminar NaN
data = data.dropna(subset=['SALARY'])

data.head()
# Out:
#   FIRST NAME   LAST NAME SEX         DOJ CURRENT DATE DESIGNATION   AGE  \
# 0     TOMASA       ARMEN   F   5-18-2014   01-07-2016     Analyst  21.0
# 1      ANNIE         NaN   F         NaN   01-07-2016   Associate   NaN
# 2      OLIVE        ANCY   F   7-28-2014   01-07-2016     Analyst  21.0
# 3     CHERRY     AQUILAR   F  04-03-2013   01-07-2016     Analyst  22.0
# 4       LEON  ABOULAHOUD   M  11-20-2014   01-07-2016     Analyst   NaN
#
#    SALARY        UNIT  LEAVES USED  LEAVES REMAINING  RATINGS  PAST EXP
# 0   44570     Finance         24.0               6.0      2.0         0
# 1   89207         Web          NaN              13.0      NaN         7
# 2   40955     Finance         23.0               7.0      3.0         0
# 3   45550          IT         22.0               8.0      3.0         0
# 4   43161  Operations         27.0               3.0      NaN         3

# %%
# Crear un grafico
plt.figure(figsize=(10, 6))
sns.kdeplot(data['SALARY'], fill=True, color='b')
plt.title('Distribucion de Densidad')
plt.xlabel('Salario')
plt.ylabel('Densidad')
plt.grid(True)
plt.show()
